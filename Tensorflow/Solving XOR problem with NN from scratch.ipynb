# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Architecture
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Our possible dataset
# `
# X = [
#         [X11, X12],
#         [X21, X22],
#         [X31, X32],
#         [X41, X42]
#     ]
# `
#
# 2 features so 2 input neurons

# %%
X = [
    [0, 1],
    [1, 0],
    [0, 0],
    [1, 1]
]

# %%
# Weight dimension - One row per input neuron and one column per artificial neuron in the layer

# weights for layer 1
WL1 = [
    [1, 1],
    [-1, 1],
]

# bias for layer 1
BL1 = [-1.5, -0.5]

# %%
# weights for layer 2
WL2 = [
    [-1, 1, ],
]

# bias for layer 2
BL2 = [-0.5]

# %%
X = np.array(X)
WL1 = np.array(WL1)
BL1 = np.array(BL1)
WL2 = np.array(WL2)
BL2 = np.array(BL2)

# %%
N1 = np.dot(X[0][0])

# %%
x = np.array([
    [1,2],
    [3,4]
])
y = np.array([
    [11,12],
    [13, 14]
])

# %%
np.dot(x, y)
# Out:
# array([[37, 40],
#        [85, 92]])

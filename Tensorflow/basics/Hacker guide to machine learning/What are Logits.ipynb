# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Logits
#
# ### 1. What are logits?
#  - Logits are values between [-inf to +inf]
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Logits are the input to softmax
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## How softmax calculate probability from logits

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ----

# %% [markdown]
# # What are logits
# # How logits determine the probability => tell its unnormalised
# # When p = 100%, logit is +inf, at p = 0% logit is -inf
# # Softmax with logit

# %%
e=2.7
e**-5
# Out:
# 0.0069691719376256305

# %%
e**5
# Out:
# 143.48907000000005

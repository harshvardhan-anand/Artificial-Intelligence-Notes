# %% [markdown]
# # Concept Included
# **1. OCR of whole image.**
#
# **2. OCR of selected text.**
#
# **3. Summarization.**
#
# **4. Context tagging.**
#
# **5. Sentiment Analysis.**
#
# **6. Find related searches on internet.**
#
# **7. GUI**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[10, 20])
img  = plt.imread('morg.jpg')
plt.imshow(img)

# %%
import pytesseract as ocr

# file executable file path, installed from exe file
ocr.pytesseract.tesseract_cmd = r'C:\Users\Brothers\AppData\Local\Tesseract-OCR\tesseract.exe'

ocr.get_tesseract_version()
# Out:
# LooseVersion ('5.0.0-alpha.20200328')

# %%
# tesseract expects image in RGB not in BGR, take care when reading from cv2
ocr.image_to_string(img)
# Out:
# '=. Life cannot be\n= changed in a minute\nbut\nDecision taken in a minute\nchanges everything in life\nAlways stay calm\n[ke before you Decide\n\n+\n\nGS RANJIT GOOD MORNING'
